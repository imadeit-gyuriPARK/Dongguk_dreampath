# %% [markdown]
# # 최종 집계 — 학교별 댓글 수
#
# `4.1-gt-match.ipynb`가 저장한 `data/processed/fin_result.csv`의 `ans` 컬럼(댓글당 매칭된
# 정식 학교명, 여러 개면 공백 구분)을 펼쳐서 학교별로 카운트.

# %%
import sys
from pathlib import Path


def find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src").is_dir() and (p / "data").is_dir():
            return p
    raise FileNotFoundError("repo 루트를 못 찾았어요 (data/, src/ 폴더 기준)")


REPO_ROOT = find_repo_root(Path.cwd())
if str(REPO_ROOT / "src" / "utils") not in sys.path:
    sys.path.append(str(REPO_ROOT / "src" / "utils"))

REPO_ROOT
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath')

# %%
import pandas as pd

df = pd.read_csv(
    REPO_ROOT / "data" / "processed" / "fin_result.csv", encoding="utf-8-sig"
)
df["ans"] = df["ans"].fillna("")
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## ans를 펼쳐서 학교별 댓글 수 집계
#
# `4.1-gt-match.ipynb`에서 ans_count==0(16건)/==2(49건)/구조 검증 실패(5건)를 전부 보정해서
# 지금은 `ans_count`가 모든 행에서 1건. 그래서 아래 집계 총합은 정확히 1,000건.

# %%
# ans에 학교가 공백으로 여러 개 있으면(예: "잠실초등학교 대치초등학교") 각각 +1씩 카운트
all_schools = [school for match in df["ans"] for school in match.split()]

school_counts = pd.Series(all_schools).value_counts().sort_values(ascending=False)
school_counts.index.name = "학교명"
school_counts.name = "count"
school_counts
# Out:
# 학교명
# 이화여자대학교사범대학부속이화·금란중학교    50
# 서초초등학교                   45
# 인하대학교사범대학부속중학교           45
# 인하대학교                    42
# 서울고등학교                   42
# 서초중학교                    41
# 잠원초등학교                   41
# 인하대학교사범대학부속고등학교          40
# 이화여자대학교사범대학부속이화금란고등학교    39
# 이화여자대학교사범대학부속초등학교        38
# 대치중학교                    35
# 이화여자대학교                  35
# 잠실중학교                    34
# 한양대학교                    32
# 건국대학교                    31
# 중동고등학교                   30
# 휘문고등학교                   30
# 대치초등학교                   30
# 서울대학교                    30
# 경기고등학교                   29
# 서강대학교                    28
# 반포중학교                    28
# 연세대학교                    27
# 인하대학교부속초등학교              26
# 고려대학교                    23
# 성균관대학교                   23
# 중앙대학교                    19
# 반포초등학교                   19
# 서울공업고등학교                 17
# 서울공고등학교                  17
# 인하부초등학교                  13
# 인하대학교부속고등학교               7
# 이화여자대학교부속고등학교             6
# 인하대학교부속중학교                5
# 동국대학교                     1
# 인하대학교사범대학부속초등학교           1
# 이화여자대학교부속초등학교             1
# Name: count, dtype: int64

# %%
out_path = REPO_ROOT / "results" / "school_counts_2026-08-22" / "school_counts.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
school_counts.to_csv(out_path, encoding="utf-8-sig")
out_path
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath/results/school_counts_2026-08-01/school_counts.csv')
