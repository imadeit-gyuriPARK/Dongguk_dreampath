# %% [markdown]
# # 최종 집계 — 학교별 댓글 수
#
# `4.0-gt-match.ipynb`가 저장한 `data/interim/gt_match_results.csv`의 `ans` 컬럼(댓글당 매칭된
# 정식 학교명, 여러 개면 공백 구분)을 펼쳐서 학교별로 카운트.

# %%
import sys
from pathlib import Path


def find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src").is_dir() and (p / "data").is_dir():
            return p
    raise FileNotFoundError("repo 루트를 못 찾았어요 (data/, src/ 폴더 기준)")


REPO_ROOT = find_repo_root(Path.cwd())
if str(REPO_ROOT / "src" / "data") not in sys.path:
    sys.path.append(str(REPO_ROOT / "src" / "data"))

REPO_ROOT
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath')

# %%
import pandas as pd

df = pd.read_csv(
    REPO_ROOT / "data" / "interim" / "gt_match_results.csv", encoding="utf-8-sig"
)
df["ans"] = df["ans"].fillna("")
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## ans를 펼쳐서 학교별 댓글 수 집계
#
# 한 댓글에 학교가 2개 이상 언급된 경우(`ans_count >= 2`), 시간 관계상 어느 쪽이 진짜 정답인지
# 판단하는 로직은 만들지 못해서 **둘 다 그대로 카운트**함. 그래서 아래 집계 총합은 1,000건보다
# 클 수 있음 — 이건 알려진 한계점.

# %%
# ans에 학교가 공백으로 여러 개 있으면(예: "잠실초등학교 대치초등학교") 각각 +1씩 카운트
all_schools = [school for match in df["ans"] for school in match.split()]

school_counts = pd.Series(all_schools).value_counts().sort_values(ascending=False)
school_counts.index.name = "학교명"
school_counts.name = "count"
school_counts
# Out:
# 학교명
# 인하대학교사범대학부속중학교           51
# 이화여자대학교사범대학부속이화·금란중학교    50
# 인하대학교                    44
# 서초초등학교                   43
# 서초중학교                    42
# 잠원초등학교                   42
# 이화여자대학교사범대학부속이화금란고등학교    42
# 이화여자대학교사범대학부속초등학교        40
# 서울고등학교                   40
# 인하대학교사범대학부속고등학교          39
# 이화여자대학교                  37
# 한양대학교                    36
# 대치중학교                    35
# 잠실중학교                    33
# 중동고등학교                   32
# 건국대학교                    32
# 서울대학교                    31
# 서강대학교                    30
# 반포중학교                    30
# 휘문고등학교                   29
# 대치초등학교                   29
# 연세대학교                    29
# 경기고등학교                   28
# 인하대학교부속초등학교              26
# 중앙대학교                    25
# 성균관대학교                   25
# 고려대학교                    24
# 반포초등학교                   19
# 서울공업고등학교                 16
# 서울공고등학교                  16
# 인하부초등학교                  12
# 인하대학교부속고등학교               7
# 이화여자대학교부속고등학교             6
# ...

# %%
out_path = REPO_ROOT / "results" / "school_counts_2026-08-01" / "school_counts.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
school_counts.to_csv(out_path, encoding="utf-8-sig")
out_path
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath/results/school_counts_2026-08-01/school_counts.csv')
