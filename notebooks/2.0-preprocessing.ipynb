# %% [markdown]
# # 전처리 파이프라인 — 학교명 댓글 데이터셋

# %%
import sys
from pathlib import Path

# 커널이 어디서 시작되든(repo 루트든 src/ 안이든) 항상 동작하도록
# data/, src/ 폴더를 둘 다 가진 위치를 repo 루트로 잡는다.
def find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src").is_dir() and (p / "data").is_dir():
            return p
    raise FileNotFoundError("repo 루트를 못 찾았어요 (data/, src/ 폴더 기준)")

REPO_ROOT = find_repo_root(Path.cwd())
if str(REPO_ROOT / "src" / "data") not in sys.path:
    sys.path.append(str(REPO_ROOT / "src" / "data"))

REPO_ROOT
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath')

# %%
import pandas as pd

df = pd.read_csv(REPO_ROOT / "data" / "raw" / "dataset.csv", encoding="utf-8")
df.shape
# Out:
# (1000, 2)

# %% [markdown]
# ## 전처리 1단계 — 이모지 / ㅋㅋㅎㅎ / 문장부호 제거

# %%
from preprocessing import clean_text

df["comment_clean_1"] = df["comment"].apply(clean_text)
df[["comment", "comment_clean_1"]].head(20)
# Out:
#                                          comment  \
# 0                                          동국대학교
# 1                                이번엔 중동고 차례입니다 🍗
# 2                        우리 반/동아리 대표로 서초초 신청합니다!
# 3                     잠실중 친구가 놀러왔지만 치킨은 건국대로 주세요
# 4   이화여대부속초 친구랑 서초초 친구 같이 보고 있는데 저는 이화여대부속초로 신청!
# 5                          학식 말고 치킨 먹고 싶어요 인하대학교
# 6                              서울공업고.. 오늘만 기다렸어요
# 7                                    서강대 학생들 모여라
# 8                               동아리방에서 기다릴게요 서초중
# 9                            대치중 학생입니다 대치중 뽑아주세요
# 10                               시험기간엔 서초초 치킨이 답
# 11                     오늘 회의 많은데 서초중 치킨 지원 부탁드려요
# 12                              동아리방에서 기다릴게요 휘문고
# 13                              인하대부속초 / 치킨 / 제발
# 14                      잠원초등학교 학생입니다. 이벤트 참여합니다.
# 15                              시험기간엔 이화여대 치킨이 답
# 16                         잠실중 학생들 야근 말고 치킨 먹자 🙏
# 17                              동아리방에서 기다릴게요 대치초
# 18                            학식 말고 치킨 먹고 싶어요 연대
# 19                              동아리방에서 기다릴게요 대치중
#
#                                 comment_clean_1
# 0                                         동국대학교
# 1                                 이번엔 중동고 차례입니다
# 2                        우리 반 동아리 대표로 서초초 신청합니다
# 3                    잠실중 친구가 놀러왔지만 치킨은 건국대로 주세요
# 4   이화여대부속초 친구랑 서초초 친구 같이 보고 있는데 저는 이화여대부속초로 신청
# 5                         학식 말고 치킨 먹고 싶어요 인하대학교
# 6                               서울공업고 오늘만 기다렸어요
# 7                                   서강대 학생들 모여라
# 8                              동아리방에서 기다릴게요 서초중
# 9                           대치중 학생입니다 대치중 뽑아주세요
# 10                              시험기간엔 서초초 치킨이 답
# 11                    오늘 회의 많은데 서초중 치킨 지원 부탁드려요
# 12                             동아리방에서 기다릴게요 휘문고
# 13                                 인하대부속초 치킨 제발
# 14                       잠원초등학교 학생입니다 이벤트 참여합니다
# 15                             시험기간엔 이화여대 치킨이 답
# 16                          잠실중 학생들 야근 말고 치킨 먹자
# 17                             동아리방에서 기다릴게요 대치초
# 18                           학식 말고 치킨 먹고 싶어요 연대
# 19                             동아리방에서 기다릴게요 대치중

# %%
# 실제로 뭔가 바뀐 행만 모아서 눈으로 확인
changed = df[df["comment"] != df["comment_clean_1"]]
print(f"{len(changed)}개 행에서 변경 발생")
changed[["comment", "comment_clean_1"]].head(30)
# Out:
# 491개 행에서 변경 발생
#                                          comment  \
# 1                                이번엔 중동고 차례입니다 🍗
# 2                        우리 반/동아리 대표로 서초초 신청합니다!
# 4   이화여대부속초 친구랑 서초초 친구 같이 보고 있는데 저는 이화여대부속초로 신청!
# 6                              서울공업고.. 오늘만 기다렸어요
# 13                              인하대부속초 / 치킨 / 제발
# 14                      잠원초등학교 학생입니다. 이벤트 참여합니다.
# 16                         잠실중 학생들 야근 말고 치킨 먹자 🙏
# 25                          배고픈 인하부초 학생들 살려주세요ㅠㅠ
# 31                             한양대 응원단 여기 있습니다!!
# 34                               중동고!!! 치킨 부탁드려요
# 36                               서초중!!! 치킨 부탁드려요
# 41                               서초초!!! 치킨 부탁드려요
# 43                                  서초중  치킨  가즈아
# 45                       잠실중학교 학생입니다. 이벤트 참여합니다.
# 48                          배고픈 이대부중 학생들 살려주세요ㅠㅠ
# 51                               서울공고ㅋㅋ 치킨 기다립니다
# 52                           배민 최고… 서강대도 꼭 뽑아주세요
# 54           대치초 친구랑 고대 친구 같이 보고 있는데 저는 대치초로 신청!
# 57                               경기고 경기고 치킨 주세요!
# 60                           배고픈 대치초 학생들 살려주세요ㅠㅠ
# 61                                  대치초 치킨 주세요!!
# 62                      배민 이벤트 참여합니다! 건국대로 보내주세요
# 63                   오늘 과제 끝낸 이화여대부속고 팀 치킨 가즈아ㅋㅋ
# 68                               이번엔 서울대 차례입니다 🍗
# 70                                   이대~ 꼭 뽑아주세요
# 73                           배민 최고… 중동고도 꼭 뽑아주세요
# 77                                  반포중  치킨  가즈아
# 78                           오늘은 서울고! 다시 말해 서울고!
# 79                       우리 반/동아리 대표로 서초중 신청합니다!
# 81                               이번엔 경기고 차례입니다 🍗
#
#                                 comment_clean_1
# 1                                 이번엔 중동고 차례입니다
# 2                        우리 반 동아리 대표로 서초초 신청합니다
# 4   이화여대부속초 친구랑 서초초 친구 같이 보고 있는데 저는 이화여대부속초로 신청
# 6                               서울공업고 오늘만 기다렸어요
# 13                                 인하대부속초 치킨 제발
# 14                       잠원초등학교 학생입니다 이벤트 참여합니다
# 16                          잠실중 학생들 야근 말고 치킨 먹자
# 25                           배고픈 인하부초 학생들 살려주세요
# 31                              한양대 응원단 여기 있습니다
# 34                                 중동고 치킨 부탁드려요
# 36                                 서초중 치킨 부탁드려요
# 41                                 서초초 치킨 부탁드려요
# 43                                   서초중 치킨 가즈아
# 45                        잠실중학교 학생입니다 이벤트 참여합니다
# 48                           배고픈 이대부중 학생들 살려주세요
# 51                                서울공고 치킨 기다립니다
# 52                           배민 최고 서강대도 꼭 뽑아주세요
# 54           대치초 친구랑 고대 친구 같이 보고 있는데 저는 대치초로 신청
# 57                               경기고 경기고 치킨 주세요
# 60                            배고픈 대치초 학생들 살려주세요
# 61                                   대치초 치킨 주세요
# 62                      배민 이벤트 참여합니다 건국대로 보내주세요
# 63                    오늘 과제 끝낸 이화여대부속고 팀 치킨 가즈아
# 68                                이번엔 서울대 차례입니다
# 70                                   이대 꼭 뽑아주세요
# 73                           배민 최고 중동고도 꼭 뽑아주세요
# 77                                   반포중 치킨 가즈아
# 78                            오늘은 서울고 다시 말해 서울고
# 79                       우리 반 동아리 대표로 서초중 신청합니다
# 81                                이번엔 경기고 차례입니다

# %%
df.head(1)
# Out:
#   comment_id comment comment_clean_1
# 0      C0001   동국대학교           동국대학교

# %% [markdown]
# ## 전처리 2단계 — 동사/형용사/조사 제거

# %%
from preprocessing import clean_pos

df["comment_noun"] = df["comment_clean_1"].apply(clean_pos)
df[["comment", "comment_noun"]].head(20)
# Out:
#                                          comment  \
# 0                                          동국대학교
# 1                                이번엔 중동고 차례입니다 🍗
# 2                        우리 반/동아리 대표로 서초초 신청합니다!
# 3                     잠실중 친구가 놀러왔지만 치킨은 건국대로 주세요
# 4   이화여대부속초 친구랑 서초초 친구 같이 보고 있는데 저는 이화여대부속초로 신청!
# 5                          학식 말고 치킨 먹고 싶어요 인하대학교
# 6                              서울공업고.. 오늘만 기다렸어요
# 7                                    서강대 학생들 모여라
# 8                               동아리방에서 기다릴게요 서초중
# 9                            대치중 학생입니다 대치중 뽑아주세요
# 10                               시험기간엔 서초초 치킨이 답
# 11                     오늘 회의 많은데 서초중 치킨 지원 부탁드려요
# 12                              동아리방에서 기다릴게요 휘문고
# 13                              인하대부속초 / 치킨 / 제발
# 14                      잠원초등학교 학생입니다. 이벤트 참여합니다.
# 15                              시험기간엔 이화여대 치킨이 답
# 16                         잠실중 학생들 야근 말고 치킨 먹자 🙏
# 17                              동아리방에서 기다릴게요 대치초
# 18                            학식 말고 치킨 먹고 싶어요 연대
# 19                              동아리방에서 기다릴게요 대치중
#
#                           comment_noun
# 0                                동국대학교
# 1                            이번 중동고 차례
# 2                   우리 반 동아리 대표 서초초 신청
# 3                        잠실중 친구 치킨 건국대
# 4   이화여대부속초 친구 서초초 같이 보고 저 이화여대부속초로 신청
# 5                          학식 치킨 인하대학교
# 6                              서울공업 오늘
# 7                              서강대 학생들
# 8                             동아리방 서초중
# 9                               대치중 학생
# 10                       시험기간 서초초 치킨 답
# 11                     오늘 회의 서초중 치킨 지원
# 12                            동아리방 휘문고
# 13                        인하대부속초 치킨 제발
# 14                    잠원초등학교 학생 이벤트 참여
# 15                      시험기간 이화여대 치킨 답
# 16                       잠실중 학생들 야근 치킨
# 17                            동아리방 대치초
# 18                            학식 치킨 연대
# 19                            동아리방 대치중

# %%
out_path = REPO_ROOT / "data" / "interim" / "preprocessing.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
df[["comment_id", "comment", "comment_clean_1", "comment_noun"]].to_csv(
    out_path, index=False, encoding="utf-8-sig"
)
out_path
# Out:
# WindowsPath('D:/Study/dongguk_university/dreampath/data/interim/preprocessing.csv')
