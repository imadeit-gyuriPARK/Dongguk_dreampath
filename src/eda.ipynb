# %% [markdown]
# # EDA — 학교명 댓글 데이터셋 (`data/raw/dataset.csv`)

# %%
import pandas as pd

df = pd.read_csv("../data/raw/dataset.csv", encoding="utf-8")
df.shape

# %%
df.dtypes

# %%
df.head(10)

# %% [markdown]
# ## 결측치 / 중복

# %%
df.isna().sum()

# %%
print("comment_id 중복:", df["comment_id"].duplicated().sum())
print("comment 중복:", df["comment"].duplicated().sum())

# %% [markdown]
# ## 텍스트 길이 / 샘플

# %%
df["comment"].str.len().describe()

# %%
df["comment"].sample(20, random_state=42).to_list()
